# %%
import PIL.Image as Img
import numpy as np

# %%
img = Img.open('images/gaussian_noise.png')

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1238x374 at 0x27AC6B1BF40>

# %%
mat = np.array(img)

# %%
mat.shape
# Out:
# (374, 1238, 3)

# %%
import mycv as cv

# %%
cv.yoyo()
# Out:
# 'version 1.0'

# %%
cv.version()
# Out:
# 'version 1.0'

# %%
a1 = np.array([[0, 1, 2], [2, 3, 5]])
a2 = np.array([[0, 1, 2], [2, 3, 5]])
cv.add_arrays(a1, a2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-3ccd71bb49e3> in <module>
# ----> 1 a1 = np.array([0, 1, 2], [2, 3, 5])
#       2 a2 = np.array([0, 1, 2], [2, 3, 5])
#       3 cv.add_arrays(a1, a2)
#
# TypeError: Field elements must be 2- or 3-tuples, got '2'

# %%
cv.what
# Out:
# 'Hello pybind!'

# %%
a1
# Out:
# array([0, 1, 2])

# %%
cv.sub(1, 2)
# Out:
# -1
